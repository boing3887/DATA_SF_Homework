# %%
"""
1. There are 1,309 passengers in the passenger list.
2. The overall survival rate is ~38.2%
3. 843 male passengers were aboard
4. 466 female passengers were aboard
5. Male survival rate is about 0.191, or 19%
6. Female surival rate is about 0.728, or 72.8%
7.
    a.
    b.
8.
9.
10.
11.
12.
13.
14.
"""

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
titan = pd.read_csv('http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.csv')

# %%
titan.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat  body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2   NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11   NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN   NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN   135
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN   NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titan.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
#print(titan['sex'])

# %%
titan['sex'].value_counts()
# Out:
# male      843
# female    466
# dtype: int64

# %%
pd.crosstab(titan['sex'], titan['survived'])
# Out:
# survived    0    1
# sex
# female    127  339
# male      682  161

# %%
male_survive = 161/843 
female_survive = 339/466
print("Male survival rate is:", male_survive)
print("Female surival rate is:", female_survive)
# Out:
# Male survival rate is: 0.19098457888493475
# Female surival rate is: 0.7274678111587983

# %%
titan['age'].describe()
# Out:
# count    1046.000000
# mean       29.881138
# std        14.413493
# min         0.170000
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# dtype: float64

# %%
#sex_age = pd.DataFrame()

# %%
nan_age = np.isnan(titan.age)
titan[nan_age]
# Out:
#       pclass  survived                                               name  \
# 15         1         0                                Baumann, Mr. John D
# 37         1         1      Bradley, Mr. George ("George Arthur Brayton")
# 40         1         0                          Brewe, Dr. Arthur Jackson
# 46         1         0                              Cairns, Mr. Alexander
# 59         1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 69         1         1             Chibnall, Mrs. (Edith Martha Bowerman)
# 70         1         0              Chisholm, Mr. Roderick Robert Crispin
# 74         1         0                        Clifford, Mr. George Quincy
# 80         1         0                          Crafton, Mr. John Bertram
# 106        1         0                                 Farthing, Mr. John
# 107        1         1               Flegenheim, Mrs. Alfred (Antoinette)
# 108        1         1                            Fleming, Miss. Margaret
# ...

# %%
mean_age = titan['age'][~nan_age].mean()
titan['age'][nan_age] = mean_age

titan.age.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a7af8dc1b880> in <module>()
# ----> 1 mean_age = titan['age'][~nan_age].mean()
#       2 titan['age'][nan_age] = mean_age
#       3
#       4 titan.age.describe()
#
# NameError: name 'titan' is not defined

# %%
meanage_sex = titan.pivot_table('age', rows='sex', aggfunc = 'mean')
print("%.2f" % meanage_sex)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7158a4be1d94> in <module>()
# ----> 1 meanage_sex = titan.pivot_table('age', rows='sex', aggfunc = 'mean')
#       2 print("%.2f" % meanage_sex)
#
# NameError: name 'titan' is not defined

# %%
meanage_sex['female']
# Out:
# 28.886950081651719

# %%
meanage_sex['male']
# Out:
# 30.430712299467633

# %%
group = titan.groupby(['sex','age'])

# %%
titan['sex']
# Out:
# 0     female
# 1       male
# 2     female
# 3       male
# 4     female
# 5       male
# 6     female
# 7       male
# 8     female
# 9       male
# 10      male
# 11    female
# 12    female
# 13    female
# 14      male
# ...
# 1294      male
# 1295      male
# 1296      male
# 1297      male
# 1298      male
# 1299      male
# 1300    female
# 1301      male
# 1302      male
# 1303      male
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object
